# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv("..//data//Life_Expectancy_Data.csv",sep=",")

# %%
# Identify countries with a lot of records
_counts = data['Country'].value_counts()
# Define the threshold for considering a countries to have a lot of records
threshold = 2  
selected_ = _counts[_counts >= threshold].index.tolist()
# Filter the data for selected countries
filtered_data = data[data['Country'].isin(selected_)]
# Split the filtered data into training and testing sets
X_train, X_test = train_test_split(filtered_data, test_size=0.2, random_state=42, stratify=filtered_data['Country'])
#X_test = X_test.drop(columns=['Life expectancy '])
# Saving train and test sets to CSV files
X_train.to_csv('..//data//train.csv', index=False)
X_test.to_csv('..//data//test.csv', index=False)

# %%
filtered_data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
print(selected_)
# Out:
# ['Afghanistan', 'Peru', 'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Philippines', 'Lebanon', 'Poland', 'Portugal', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'New Zealand', 'Netherlands', 'Nepal', 'Namibia', 'Liberia', 'Albania', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia (Federated States of)', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe', 'The former Yugoslav republic of Macedonia', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom of Great Britain and Northern Ireland', 'United Republic of Tanzania', 'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian 
# ...

# %%
for i in data.columns:
    print( data[i].value_counts(),'\n\n')
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64
#
#
# Year
# 2013    193
# 2015    183
# 2014    183
# 2012    183
# 2011    183
# 2010    183
# 2009    183
# 2008    183
# 2007    183
# 2006    183
# 2005    183
# 2004    183
# 2003    183
# 2002    183
# 2001    183
# 2000    183
# Name: count, dtype: int64
#
#
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
#
#
# Life expectancy
# 73.0    45
# 75.0    33
# 78.0    31
# 73.6    28
# 73.9    25
#         ..
# 43.1     1
# 49.5     1
# 49.0     1
# 55.1     1
# 45.4     1
# Name: count, Length: 362, dtype: int64
#
#
# Adult Mortality
# 12.0     34
# 14.0     30
# 16.0     29
# ...
